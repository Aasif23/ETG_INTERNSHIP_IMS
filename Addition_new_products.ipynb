# %%
products = {
    1001 : {"name":"Dorito's Nacho Chips",    "price":90,   "quan":360, "expiry":"22 jan 2023",  "brand":"Dorito's"},
    1002 : {"name":"Thums Up Soft Drink",     "price":40,   "quan":60,  "expiry":"20 dec 2024",  "brand":"Thums Up"},
    1003 : {"name":"Svami Soda Water",        "price":55,   "quan":70,  "expiry":"20 jun 2023",  "brand":"Svami"},
    1004 : {"name":"Coca-Cola",               "price":65,   "quan":60,  "expiry":"22 jul 2023",  "brand":"Coca Cola"},
    1005 : {"name":"Sprite Lime Flavor",      "price":89,   "quan":40,  "expiry":"20 nov 2023",  "brand":"Sprite"},
    1006 : {"name":"Colgate Maxfresh",        "price":215,  "quan":55,  "expiry":"20 jun 2024",  "brand":"Colgate"},
    1007 : {"name":"Pepsodent Gum Care",      "price":300,  "quan":150, "expiry":"15 jul 2022",  "brand":"Pepsodent"},
    1008 : {"name":"Dabur Amla Hair Oil",     "price":247,  "quan":100, "expiry":"10 aug 2024",  "brand":"DABUR"},
    1009 : {"name":"Nivea Men Face Wash",     "price":149,  "quan":98,  "expiry":"31 jul 2022",  "brand":"Nivea"},
    1010 : {"name":"Himalaya Herbal Face wash","price":104, "quan":200, "expiry":"22 may 2022",  "brand":"Himalaya"},
    1011: {"name":"Himalaya Baby Powder",    "price":243,  "quan":150, "expiry":"31 may 2024",  "brand":"Himalaya"},
    1012 : {"name":"Nivea Talcum Powder",     "price":199,  "quan":120, "expiry":"31 may 2024",  "brand":"Nivea"},
    1013 : {"name":"Fogg Xtremo Scent",       "price":299,  "quan":155, "expiry":"01 jan 2024",  "brand":"FOGG"},
    1014 : {"name":"Villain Perfume men",     "price":555,  "quan":230, "expiry":"31 may 2024",  "brand":"Villian"},
    1015 : {"name":"Dairy Milk Silk",         "price":475,  "quan":50,  "expiry":"31 jan 2022",  "brand":"Cadbury"},
    1016 : {"name":"Pillsbury cookes cake",   "price":90,   "quan":200, "expiry":"02 dec 2021",  "brand":"Pillsbury"},
    1017 : {"name":"Kraft Oreo Soft Cake",    "price":249,  "quan":120, "expiry":"30 dec 2021",  "brand":"Ore0"},
    1018 : {"name":"Mom's Magic Cashew",      "price":80,   "quan":180, "expiry":"19 mar 2022",  "brand":"Sunfeast"},
    1019 : {"name":"Cadbury Oreo chacolate",  "price":60,   "quan":185, "expiry":"19 feb 2022",  "brand":"Cadbury"},
    1020 : {"name":"Betty Croker Pancake",    "price":346,  "quan":190, "expiry":"15 jan 2022",  "brand":"Betty Croker"},
    1021 : {"name":"Parle G Original",        "price":67,   "quan":140, "expiry":"13 dec 2011",  "brand":"Parle"},
    1022 : {"name":"Lays Potato Chips",       "price":30,   "quan":450, "expiry":"14 feb 2023",  "brand":"Lay's"},
    1023 : {"name":"Bingo! Mad Angle",        "price":25,   "quan":440, "expiry":"20 dec 2023",  "brand":"Bingo!"},
    1024 : {"name":"Kellogg's pringles",      "price":85,   "quan":400, "expiry":"25 jan 2024",  "brand":"Kellog's"},
    1025 : {"name":"Pepsi Can",               "price":153,  "quan":50,  "expiry":"20 oct 2023",  "brand":"Pepsi"},
    1026 : {"name":"Tata Salt",               "price":20,   "quan":130, "expiry":"12 jan 2022",  "brand":"Tata"},
    1027 : {"name":"Tata Tea Gold",           "price":48,   "quan":145, "expiry":"10 mar 2023",  "brand":"Tata"},
    1028 : {"name":"Turmeric Powder",         "price":52,   "quan":122, "expiry":"23 jun 2023",  "brand":"Tata"},
    1029 : {"name":"Quaker Oats",             "price":285,  "quan":30,  "expiry":"30 oct 2022",  "brand":"Quaker"},
    1030 : {"name":"Saffola Active",          "price":207,  "quan":58,  "expiry":"29 jan 2022",  "brand":"Saffola"},
    1031 : {"name":"Kitkat Desert",           "price":55,   "quan":59,  "expiry":"31 aug 2022",  "brand":"Nestle"},
    1032 : {"name":"Dark Fantasy Choco Fills","price":90,   "quan":90,  "expiry":"21 feb 2022",  "brand":"Dark Fantasy"},
    1033 : {"name":"Candyman Fantasy",        "price":80,   "quan":95,  "expiry":"28 dec 2021",  "brand":"Candyman Fantastik"}
    
}

# %%
products
# Out:
# {1001: {'brand': "Dorito's",
#   'expiry': '22 jan 2023',
#   'name': "Dorito's Nacho Chips",
#   'price': 90,
#   'quan': 360},
#  1002: {'brand': 'Thums Up',
#   'expiry': '20 dec 2024',
#   'name': 'Thums Up Soft Drink',
#   'price': 40,
#   'quan': 60},
#  1003: {'brand': 'Svami',
#   'expiry': '20 jun 2023',
#   'name': 'Svami Soda Water',
#   'price': 55,
#   'quan': 70},
#  1004: {'brand': 'Coca Cola',
#   'expiry': '22 jul 2023',
#   'name': 'Coca-Cola',
#   'price': 65,
#   'quan': 60},
#  1005: {'brand': 'Sprite',
#   'expiry': '20 nov 2023',
#   'name': 'Sprite Lime Flavor',
#   'price': 89,
#   'quan': 40},
#  1006: {'brand': 'Colgate',
#   'expiry': '20 jun 2024',
#   'name': 'Colgate Maxfresh',
#   'price': 215,
#   'quan': 55},
#  1007: {'brand': 'Pepsodent',
#   'expiry': '15 jul 2022',
#   'name': 'Pepsodent Gum Care',
#   'price': 300,
#   'quan': 150},
#  1008: {'brand': 'DABUR',
#   'expiry': '10 aug 2024',
#   'name': 'Dabur Amla Hair Oil',
#   'price': 247,
# ...

# %%
import json

# %%
js = json.dumps(products)

# %%
fd = open("products.json",'w')

fd.write(js)

fd.close()

# %%
fd = open("products.json",'r')

r = fd.read()

fd.close()

# %%
products = json.loads(r)

# %%
products
# Out:
# {'1001': {'brand': "Dorito's",
#   'expiry': '22 jan 2023',
#   'name': "Dorito's Nacho Chips",
#   'price': 90,
#   'quan': 360},
#  '1002': {'brand': 'Thums Up',
#   'expiry': '20 dec 2024',
#   'name': 'Thums Up Soft Drink',
#   'price': 40,
#   'quan': 60},
#  '1003': {'brand': 'Svami',
#   'expiry': '20 jun 2023',
#   'name': 'Svami Soda Water',
#   'price': 55,
#   'quan': 70},
#  '1004': {'brand': 'Coca Cola',
#   'expiry': '22 jul 2023',
#   'name': 'Coca-Cola',
#   'price': 65,
#   'quan': 60},
#  '1005': {'brand': 'Sprite',
#   'expiry': '20 nov 2023',
#   'name': 'Sprite Lime Flavor',
#   'price': 89,
#   'quan': 40},
#  '1006': {'brand': 'Colgate',
#   'expiry': '20 jun 2024',
#   'name': 'Colgate Maxfresh',
#   'price': 215,
#   'quan': 55},
#  '1007': {'brand': 'Pepsodent',
#   'expiry': '15 jul 2022',
#   'name': 'Pepsodent Gum Care',
#   'price': 300,
#   'quan': 150},
#  '1008': {'brand': 'DABUR',
#   'expiry': '10 aug 2024',
#   'name': 'Dabur Amla Hair Oil',
# ...

# %% [markdown]
# # Add New Item into Inventory

# %%
prod_id = input("Enter the Product ID: ")
name = input("Enter the Name of the Product: ")
price = int(input("Enter the price per Item: "))
quan = int(input("Enter The Quantity of the Product you want to add: "))
expiry = input("Enter the expiry date of the Product: ")
brand = input("Enter the Brand of the product: ")

products[prod_id] = {"name":name,"price":price,"quan":quan,"expiry":expiry,"brand":brand}

js = json.dumps(products)

fd = open("products.json","w")
fd.write(js)
fd.close()
# Out:
# Enter the Product ID: 1034
# Enter the Name of the Product: N95 Mask
# Enter the price per Item: 200
# Enter The Quantity of the Product you want to add: 45
# Enter the expiry date of the Product: 08 May 2022
# Enter the Brand of the product: DR.Reddy
